# %%
#WAVE INTERFERENCE
from math import sqrt,sin,pi
from numpy import empty
from pylab import *

wavelength = 5.0
k = 2*pi/wavelength
xi0 = 1.0# 振幅1.0cm
separation = 20.0#两个点相隔20cm
side = 100.0#我们考虑一个1m*1m的区域
points = 500#用500*500个点
spacing = side/points#每两个点相聚0.2cm

#放置两个波源
x1 = side/2 + separation/2
y1 = side/2
x2 = side/2 - separation/2
y2 = side/2

xi = empty([points,points],float)

for i in range(points):
    y = spacing*i
    for j in range(points):
        x = spacing*j
        r1 = sqrt((x-x1)**2+(y-y1)**2)
        r2 = sqrt((x-x2)**2+(y-y2)**2)
        xi[i,j] = xi0*sin(k*r1) + xi0*sin(k*r2)
imshow(xi,origin = "lower",extent = [0,side,0,side])
gray()
show()

# %%
from vpython import sphere,color
import vector
from numpy import vectorize
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-80546484ace0> in <module>
#       2 import vector
#       3 from numpy import vectorize
# ----> 4 a=vector(1,1,1)
#       5 sphere(pos=a,radius=0.5)
#
# TypeError: 'module' object is not callable

# %%
from vpython import sphere,color
L=5
R = 0.3
for i in range(-L,L+1):
    for j in range(-L,L+1):
        for k in range(-L,L+1):
            sphere(pos=(i,j,k),radius=R)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-7521fae04ac2> in <module>
#       5     for j in range(-L,L+1):
#       6         for k in range(-L,L+1):
# ----> 7             sphere(pos=(i,j,k),radius=R)
#
# ~/anaconda3/lib/python3.7/site-packages/vpython/vpython.py in __init__(self, **args)
#    1103         args['_default_size'] = vector(2,2,2)
#    1104         args['_objName'] = "sphere"
# -> 1105         super(sphere, self).setup(args)
#    1106
#    1107     @property
#
# ~/anaconda3/lib/python3.7/site-packages/vpython/vpython.py in setup(self, args)
#     627                 val = args[a]
#     628                 if isinstance(val, vector): setattr(self, '_'+a, vector(val))  ## '_' bypasses setters; copy of val
# --> 629                 else: raise AttributeError(a+' must be a vector')
#     630                 del args[a]
#     631
#
# ...

# %%
pip install vector
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/vector/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from vpython import sphere,rate
from math import cos,sin,pi
from numpy import arange

s = sphere(pos=[1,0,0],radius=0.1)
for theta in arange(0,10*pi,0.1):
    rate(30)
    x = cos(theta)
    y = sin(theta)
    s.pos = [x,y,0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-932344e08656> in <module>
#       3 from numpy import arange
#       4
# ----> 5 s = sphere(pos=[1,0,0],radius=0.1)
#       6 for theta in arange(0,10*pi,0.1):
#       7     rate(30)
#
# ~/anaconda3/lib/python3.7/site-packages/vpython/vpython.py in __init__(self, **args)
#    1103         args['_default_size'] = vector(2,2,2)
#    1104         args['_objName'] = "sphere"
# -> 1105         super(sphere, self).setup(args)
#    1106
#    1107     @property
#
# ~/anaconda3/lib/python3.7/site-packages/vpython/vpython.py in setup(self, args)
#     627                 val = args[a]
#     628                 if isinstance(val, vector): setattr(self, '_'+a, vector(val))  ## '_' bypasses setters; copy of val
# --> 629                 else: raise AttributeError(a+' must be a vector')
#     630                 del args[a]
# ...
